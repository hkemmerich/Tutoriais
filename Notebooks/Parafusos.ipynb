# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import csv
import matplotlib.pyplot as plt
import xlrd
import csv
import os
import glob
import codecs
import io

# %%
parafusos = pd.read_csv('Parafusos.csv', sep=',')
parafusos.head(100)
# Out:
#      P1 -  Beam Probe Display Time [s]  ... P784 -  Beam Probe 112 Moment At J [N mm]
# Name                                P1  ...                                      P784
# DP 0                                 0  ...                          6985.96088378613
# DP 1                               0.2  ...                        1393.8604470288155
# DP 2                               0.4  ...                         2795.499626960348
# DP 3                               0.7  ...                         4891.622852324519
# DP 4                                 1  ...                          6985.96088378613
#
# [6 rows x 784 columns]

# %%
parafuso = parafusos.transpose().reset_index(col_level=0)
parafuso = parafuso.drop(parafuso.index[1:112])
parafuso.head(10)
# Out:
#                                     index  ...                 DP 4
# 0       P1 -  Beam Probe Display Time [s]  ...                    1
# 112    P113 -  Beam Probe Axial Force [N]  ...   18.718830108642578
# 113  P114 -  Beam Probe 2 Axial Force [N]  ...   30.377517700195313
# 114  P115 -  Beam Probe 3 Axial Force [N]  ...   30.722366333007813
# 115  P116 -  Beam Probe 4 Axial Force [N]  ...         57.646484375
# 116  P117 -  Beam Probe 5 Axial Force [N]  ...  -11.230443000793457
# 117  P118 -  Beam Probe 6 Axial Force [N]  ...  -4.7173428535461426
# 118  P119 -  Beam Probe 7 Axial Force [N]  ...  -5.2543792724609375
# 119  P120 -  Beam Probe 8 Axial Force [N]  ...  -7.7004542350769043
# 120  P121 -  Beam Probe 9 Axial Force [N]  ...     1340.84619140625
#
# [10 rows x 7 columns]

# %%
parafuso = parafuso.reset_index(col_level=0)
parafuso.head()
# Out:
#    level_0  ...                DP 4
# 0        0  ...                   1
# 1      112  ...  18.718830108642578
# 2      113  ...  30.377517700195313
# 3      114  ...  30.722366333007813
# 4      115  ...        57.646484375
#
# [5 rows x 8 columns]

# %%
parafuso = parafuso.drop(['level_0', 'Name'], axis=1)
parafuso.head(10)
# Out:
#                                   index  ...                 DP 4
# 0     P1 -  Beam Probe Display Time [s]  ...                    1
# 1    P113 -  Beam Probe Axial Force [N]  ...   18.718830108642578
# 2  P114 -  Beam Probe 2 Axial Force [N]  ...   30.377517700195313
# 3  P115 -  Beam Probe 3 Axial Force [N]  ...   30.722366333007813
# 4  P116 -  Beam Probe 4 Axial Force [N]  ...         57.646484375
# 5  P117 -  Beam Probe 5 Axial Force [N]  ...  -11.230443000793457
# 6  P118 -  Beam Probe 6 Axial Force [N]  ...  -4.7173428535461426
# 7  P119 -  Beam Probe 7 Axial Force [N]  ...  -5.2543792724609375
# 8  P120 -  Beam Probe 8 Axial Force [N]  ...  -7.7004542350769043
# 9  P121 -  Beam Probe 9 Axial Force [N]  ...     1340.84619140625
#
# [10 rows x 6 columns]

# %%
parafuso.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 673 entries, 0 to 672
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   index   673 non-null    object
#  1   DP 0    673 non-null    object
#  2   DP 1    673 non-null    object
#  3   DP 2    673 non-null    object
#  4   DP 3    673 non-null    object
#  5   DP 4    673 non-null    object
# dtypes: object(6)
# memory usage: 31.7+ KB

# %%
def nome:
  if index < 10:
    print('Beam Probe Axial Forca [N]')

# %%
parafuso = parafuso.drop(parafuso.index[1:112])
parafuso = parafuso.set_index('index')
parafuso = parafuso.transpose()
parafuso.head()

# %%
para = parafuso.transpose()
para.head()

# %%
para = para.reset_index()
para.head()

# %%
para = para.drop('index', axis=1)

# %%
para = para.reset_index()
para = para.rename({0: 'Time'}, axis='index')
para.head()

# %%
para.head()

# %%
para = para.drop('index', axis=1)
para.head()

# %%
para.head()

# %%
para['Parafuso'] = para.index
para.head()

# %%
para = para.drop('contagem', axis=1)
para.head()

# %%
para = para.set_index('Parafuso').drop('Name', axis=1).transpose()
para.head()

# %%
para.head()
